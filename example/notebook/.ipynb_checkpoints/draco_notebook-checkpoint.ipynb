# %% [markdown]
# # Creating a cell tissue mesh with Draco-Stem
#
# **Draco-Stem** (**D**ual **R**econstruction by **A**djacency **C**omplex **O**ptimization - **S**AM **T**issue **E**nhanced **M**esh) is a computational pipeline allowing to convert a 3D stack containing a segmented tissue image into a FEM-ready triangular mesh of the cell interfaces.

# %%
import numpy as np
from scipy import ndimage as nd

from openalea.draco_stem.draco.draco import DracoMesh
from openalea.mesh.triangular_mesh import topomesh_to_triangular_mesh
from openalea.mesh.property_topomesh_io import save_ply_property_topomesh

# %% [markdown]
# First, let's generate a synthetic tissue image. Only the number of cells and the size of the image need to be specified, the cells divide a sphere in a rather realistic tissue-like way.

# %%
from openalea.draco_stem.data.example_image import sphere_tissue_image

n_cells = 21
size = 100
img = sphere_tissue_image(size,n_cells)
# Out:
# (100, 100, 100)

# %% [markdown]
# The output is a 3D image stack in which the backgound is labelled as 1, and each cell comes with its own label. The cells form neighboring connected regions of voxels.

# %%
from vplants.meshing.notebook_tools import vtk_show_image, vtk_show_polydata
vtk_show_image(img, width=800, height=300, alphamap='constant', bg_id=1, 
               position=(0,0,-1.5*img.shape[2]*img.resolution[2]))

# %% [markdown]
# To convert the image into an interface mesh, **Draco-Stem** operates on the adjacency relationships between tissue cells. It aims at reconstructing a *simplicial complex* joining neighboring cell barycenters. This complex constitutes the dual of the tissue geometry seen as a cellular complex.
#
# The algorithm uses an object called **DracoMesh** implementing all the steps of the pipeline. The initialization consists in extracting the adjacency tetrahedra from the image that *do not necessarily* constitute a simplicial complex.
#
# This is why the first step consists in generating a valid simplicial complex, as the Delaunay tetrahedrization of the cell barycenters. The key step of the pipeline is the **topological optimization** of this complex so that, in the end, it reflects as well as possible the adjacencies found in the image.

# %%
# Initialize the DracoMesh object with the example image
draco = DracoMesh(image=img)

draco.delaunay_adjacency_complex(surface_cleaning_criteria = [])

draco.adjacency_complex_optimization(n_iterations=1)
# Out:
# Computing volume property...
# Computing barycenter property...
# Generating the list of cells belonging to the first layer...
# --> Generating vertex topomesh
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating vertex topomesh [ 0.000200986862183 s]
# --> Generating tetrahedra topomesh
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating tetrahedra topomesh [ 0.00219511985779 s]
# Computing barycenter property...
# Generating the list of cells belonging to the first layer...
# property layer is undefined on elements of degree 0
# Creating property  layer  for degree  0
# --> Generating edge topomesh
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating edge topomesh [ 0.000516891479492 s]
# --> Generating triangulation topomesh
# 43  cell vertices
# 0  5-Cliques remaining
# 43  cell vertices (+exterior)
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating triangulation topomesh [ 0.00472497940063 s]
# property borders is undefined on elements of degree 1
# Creating property  borders  for degree  1
# property normal is undefined on elements of degree 0
# Creating property  normal  for degree  0
# _____________________________
#
# Iteration  0
# _____________________________
#
# --> Computing edge flip energy variations [
#  0.254915952682 s]
#   --> Flipped edge  40  :  [16L, 40L, 11L]  ->  [81 82]  (dE =  -20.9810616089 ) [ 0.00107789039612 s]
#   --> Flipped edge  76  :  [42L, 37L, 31L]  ->  [11 16]  (dE =  -20.9186752349 ) [ 0.000874042510986 s]
#   --> Flipped edge  60  :  [17L, 30L, 41L]  ->  [31 37]  (dE =  -20.8318914471 ) [ 0.000882863998413 s]
#   --> Flipped edge  69  :  [8L, 35L, 39L]  ->  [40 41]  (dE =  -20.7231842854 ) [ 0.000860929489136 s]
#   --> Flipped edge  32  :  [1L, 38L, 7L]  ->  [42  8]  (dE =  -20.455830337 ) [ 0.00090217590332 s]
# 5  Edges Flipped ( 0  non-optimal) [ 0.00944805145264 s]
# <-- Computing triangle flip energy variations [
#  0.234404087067 s]
# 0  Triangles Flipped ( 0  non-optimal) [ 0.0344309806824 s]
# Cell interface Jaccard (2-adjacency) :
#  0.99
# Cell vertices Jaccard  (4-adjacency) :  0.987012987013
# --> Computing edge flip energy variations [
#  0.241559028625 s]
# 0  Edges Flipped ( 0  non-optimal) [ 0.0134599208832 s]
# <-- Computing triangle flip energy variations [
#  0.236463069916 s]
# 0  Triangles Flipped ( 0  non-optimal) [ 0.0349361896515 s]
# Cell interface Jaccard (2-adjacency) :
#  0.99
# Cell vertices Jaccard  (4-adjacency) :  0.987012987013

# %% [markdown]
# At this stage, what we obtain is a tetrahedral mesh representing the adjacencies between cells in the image

# %%
mesh,_ = topomesh_to_triangular_mesh(draco.triangulation_topomesh,3,coef=0.9)
vtk_show_polydata(mesh._repr_vtk_(), width=800, height=300, colormap_name='grey',
                  intensity_range=(-1,0), position=(0,0,-1.2*img.shape[2]*img.resolution[2]))
# Out:
# --> Creating triangular mesh
# <-- Creating triangular mesh [ 0.0129950046539 s]

# %% [markdown]
# Now, to obtain a mesh of the tissue geometry, we only need to **dualize** the adjacency complex. This is a very straightforward process, in which the tetrahedra convert into vertices, the triangles into edges, and so on... Only the dimensionality is inverted, the topological relationships between elements are preserved.
#
# However, this produces cells with polygonal interfaces that need to be triangulated to be used for visualization of biophysical simulations. To ensure the quality of these triangles, several options are made available, controlling the fineness, regularity and faithfulness of the mesh.

# %%
#triangular = ['star','remeshed','realistic','flat']
triangular = ['star','split','regular','projected']
image_dual_topomesh = draco.dual_reconstruction(reconstruction_triangulation = triangular, adjacency_complex_degree=3)
# Out:
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# --> Creating vertices
# <-- Creating vertices      [
#  0.0327560901642 ]
# --> Creating edges
# <-- Creating edges         [ 0.00301098823547 ]
# --> Creating facets
# <-- Creating facets        [ 0.00387001037598 ]
# --> Creating cells
# <-- Creating cells         [ 0.000623941421509 ]
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# --> Triangulating Interfaces
#   --> Interface  0  /  99      [ 0.000196933746338 s]
# --> Triangulating Interfaces  [ 0.0124220848083 s]
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# --> Splitting edges
# --> Splitting edges             [ 0.0148680210114 s]
# --> Splitting triangles
# --> Splitting triangles         [
#  0.0534799098969 s]
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00833678245544 s]
# --> Preparing topomesh     [ 0.199100971222 s]
# _____________________________
#
#        Iteration  0
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.0116968154907 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00323104858398 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000293016433716 s]
# --> Updating distances
# <-- Updating distances       [ 0.00101184844971 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00120806694031 s]
# _____________________________
#
#       [ 0.0251669883728 s]
# _____________________________
#
#        Iteration  1
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00817704200745 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00130414962769 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00029993057251 s]
# --> Updating distances
# <-- Updating distances       [ 0.00114107131958 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00112199783325 s]
# _____________________________
#
#       [ 0.0191919803619 s]
# _____________________________
#
#        Iteration  2
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00809597969055 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00126004219055 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288963317871 s]
# --> Updating distances
# <-- Updating distances       [ 0.000963926315308 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101900100708 s]
# _____________________________
#       [ 0.0182390213013 s]
# _____________________________
#
#        Iteration  3
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00848197937012 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00161600112915 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00029993057251 s]
# --> Updating distances
# <-- Updating distances       [ 0.00101089477539 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107502937317 s]
# _____________________________
#
#       [ 0.0195081233978 s]
# _____________________________
#
#        Iteration  4
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00840306282043 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00118708610535 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000277996063232 s]
# --> Updating distances
# <-- Updating distances       [ 0.000930070877075 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.000988960266113 s]
# _____________________________
#
#       [ 0.0184659957886 s]
# _____________________________
#
#        Iteration  5
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00808715820312 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00121688842773 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00028395652771 s]
# --> Updating distances
# <-- Updating distances       [ 0.000939130783081 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00146293640137 s]
# _____________________________
#
#       [ 0.0186159610748 s]
# _____________________________
#
#        Iteration  6
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00822687149048 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00228905677795 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00046706199646 s]
# --> Updating distances
# <-- Updating distances       [ 0.00106000900269 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00111818313599 s]
# _____________________________
#
#       [ 0.0203320980072 s]
# _____________________________
#
#        Iteration  7
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00858306884766 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00129199028015 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000280141830444 s]
# --> Updating distances
# <-- Updating distances       [ 0.000936985015869 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102806091309 s]
# _____________________________
#
#       [ 0.0187861919403 s]
# _____________________________
#
#        Iteration  8
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00832104682922 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00142908096313 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000291109085083 s]
# --> Updating distances
# <-- Updating distances       [ 0.00101113319397 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00110411643982 s]
# _____________________________
#
#       [ 0.0197138786316 s]
# _____________________________
#
#        Iteration  9
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00863194465637 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00133991241455 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288009643555 s]
# --> Updating distances
# <-- Updating distances       [ 0.000972986221313 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105500221252 s]
# _____________________________
#
#       [ 0.0194230079651 s]
# _____________________________
#
#        Iteration  10
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00845909118652 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00124502182007 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000978946685791 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101900100708 s]
# _____________________________
#
#       [ 0.0187160968781 s]
# _____________________________
#
#        Iteration  11
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00852680206299 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00148415565491 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286817550659 s]
# --> Updating distances
# <-- Updating distances       [ 0.000983953475952 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0010678768158 s]
# _____________________________
#
#       [ 0.0194711685181 s]
# _____________________________
#
#        Iteration  12
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0086510181427 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00129699707031 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286102294922 s]
# --> Updating distances
# <-- Updating distances       [ 0.000999927520752 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0011088848114 s]
# _____________________________
#
#       [ 0.0192880630493 s]
# _____________________________
#
#        Iteration  13
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00809192657471 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00121212005615 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100111961365 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00109100341797 s]
# _____________________________
#
#       [ 0.0186839103699 s]
# _____________________________
#
#        Iteration  14
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00821709632874 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00185585021973 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000487089157104 s]
# --> Updating distances
# <-- Updating distances       [ 0.00158309936523 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00183987617493 s]
# _____________________________
#
#       [ 0.0234780311584 s]
# _____________________________
#
#        Iteration  15
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0120611190796 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127601623535 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00028395652771 s]
# --> Updating distances
# <-- Updating distances       [ 0.000961065292358 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105595588684 s]
# _____________________________
#
#       [ 0.0225939750671 s]
# _____________________________
#
#        Iteration  16
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00847697257996 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00140810012817 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000284910202026 s]
# --> Updating distances
# <-- Updating distances       [ 0.000967979431152 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0014591217041 s]
# _____________________________
#
#       [ 0.0193490982056 s]
# _____________________________
#
#        Iteration  17
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00840187072754 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00145697593689 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000301122665405 s]
# --> Updating distances
# <-- Updating distances       [ 0.000992059707642 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0011031627655 s]
# _____________________________
#
#       [ 0.0192840099335 s]
# _____________________________
#
#        Iteration  18
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00854301452637 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00121688842773 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000280141830444 s]
# --> Updating distances
# <-- Updating distances       [ 0.000949859619141 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101900100708 s]
# _____________________________
#
#       [ 0.0190570354462 s]
# _____________________________
#
#        Iteration  19
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00823211669922 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00141906738281 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000284194946289 s]
# --> Updating distances
# <-- Updating distances       [ 0.000977039337158 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106811523438 s]
# _____________________________
#
#       [ 0.0190260410309 s]
# _____________________________
#
#        Iteration  20
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00864601135254 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00131416320801 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000338077545166 s]
# --> Updating distances
# <-- Updating distances       [ 0.000993967056274 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107097625732 s]
# _____________________________
#
#       [ 0.019296169281 s]
# _____________________________
#
#        Iteration  21
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00838994979858 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00136399269104 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288963317871 s]
# --> Updating distances
# <-- Updating distances       [ 0.00108098983765 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106501579285 s]
# _____________________________
#
#       [ 0.0191960334778 s]
# _____________________________
#
#        Iteration  22
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00844788551331 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.0014169216156 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.00097393989563 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103306770325 s]
# _____________________________
#
#       [ 0.0191230773926 s]
# _____________________________
#
#        Iteration  23
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00858783721924 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00134301185608 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100493431091 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103092193604 s]
# _____________________________
#
#       [ 0.0192530155182 s]
# _____________________________
#
#        Iteration  24
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00816702842712 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.0012731552124 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00028395652771 s]
# --> Updating distances
# <-- Updating distances       [ 0.00102615356445 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00104093551636 s]
# _____________________________
#
#       [ 0.0183300971985 s]
# _____________________________
#
#        Iteration  25
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.0079128742218 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00137615203857 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286102294922 s]
# --> Updating distances
# <-- Updating distances       [ 0.000982999801636 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102686882019 s]
# _____________________________
#
#       [ 0.0185630321503 s]
# _____________________________
#
#        Iteration  26
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00813913345337 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00144791603088 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288963317871 s]
# --> Updating distances
# <-- Updating distances       [ 0.000993967056274 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107884407043 s]
# _____________________________
#
#       [ 0.0189650058746 s]
# _____________________________
#
#        Iteration  27
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00844097137451 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00123882293701 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000997066497803 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102400779724 s]
# _____________________________
#
#       [ 0.0188188552856 s]
# _____________________________
#
#        Iteration  28
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.0082848072052 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00152611732483 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286102294922 s]
# --> Updating distances
# <-- Updating distances       [ 0.00097918510437 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102114677429 s]
# _____________________________
#
#       [ 0.019159078598 s]
# _____________________________
#
#        Iteration  29
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00841903686523 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127005577087 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00028395652771 s]
# --> Updating distances
# <-- Updating distances       [ 0.00106287002563 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107288360596 s]
# _____________________________
#
#       [ 0.019150018692 s]
# _____________________________
#
#        Iteration  30
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00813508033752 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00133204460144 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000296115875244 s]
# --> Updating distances
# <-- Updating distances       [ 0.000982999801636 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103807449341 s]
# _____________________________
#
#       [ 0.0184049606323 s]
# _____________________________
#
#        Iteration  31
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00807619094849 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00141906738281 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000962972640991 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0010199546814 s]
# _____________________________
#
#       [ 0.0187849998474 s]
# _____________________________
#
#        Iteration  32
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00829601287842 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00132298469543 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286102294922 s]
# --> Updating distances
# <-- Updating distances       [ 0.000995874404907 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108981132507 s]
# _____________________________
#
#       [ 0.0191209316254 s]
# _____________________________
#
#        Iteration  33
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00843095779419 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00120806694031 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000289916992188 s]
# --> Updating distances
# <-- Updating distances       [ 0.00103783607483 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101804733276 s]
# _____________________________
#
#       [ 0.0187380313873 s]
# _____________________________
#
#        Iteration  34
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00849199295044 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00144910812378 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000298976898193 s]
# --> Updating distances
# <-- Updating distances       [ 0.00101613998413 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102186203003 s]
# _____________________________
#
#       [ 0.0193700790405 s]
# _____________________________
#
#        Iteration  35
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00862407684326 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00131797790527 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288009643555 s]
# --> Updating distances
# <-- Updating distances       [ 0.000980138778687 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108194351196 s]
# _____________________________
#
#       [ 0.0193479061127 s]
# _____________________________
#
#        Iteration  36
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00849485397339 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00122404098511 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000280857086182 s]
# --> Updating distances
# <-- Updating distances       [ 0.000969886779785 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0010621547699 s]
# _____________________________
#
#       [ 0.0191090106964 s]
# _____________________________
#
#        Iteration  37
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00884318351746 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00144100189209 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000287771224976 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100493431091 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103116035461 s]
# _____________________________
#
#       [ 0.0197560787201 s]
# _____________________________
#
#        Iteration  38
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00849413871765 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00124311447144 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.000977039337158 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105905532837 s]
# _____________________________
#
#       [ 0.0191149711609 s]
# _____________________________
#
#        Iteration  39
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00867891311646 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00131416320801 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000967979431152 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00104284286499 s]
# _____________________________
#
#       [ 0.0194840431213 s]
# _____________________________
#
#        Iteration  40
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00832200050354 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00139498710632 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000996112823486 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102305412292 s]
# _____________________________
#
#       [ 0.0191571712494 s]
# _____________________________
#
#        Iteration  41
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00841403007507 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127911567688 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00029993057251 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100612640381 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108408927917 s]
# _____________________________
#
#       [ 0.0192830562592 s]
# _____________________________
#
#        Iteration  42
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00858402252197 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00125908851624 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00028395652771 s]
# --> Updating distances
# <-- Updating distances       [ 0.000998973846436 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106906890869 s]
# _____________________________
#
#       [ 0.0191152095795 s]
# _____________________________
#
#        Iteration  43
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00819206237793 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00135588645935 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.00098705291748 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105810165405 s]
# _____________________________
#
#       [ 0.0190110206604 s]
# _____________________________
#
#        Iteration  44
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00831007957458 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00136184692383 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286817550659 s]
# --> Updating distances
# <-- Updating distances       [ 0.00098991394043 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108504295349 s]
# _____________________________
#
#       [ 0.0190980434418 s]
# _____________________________
#
#        Iteration  45
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00879883766174 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00128793716431 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000289916992188 s]
# --> Updating distances
# <-- Updating distances       [ 0.000983953475952 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101685523987 s]
# _____________________________
#
#       [ 0.0191829204559 s]
# _____________________________
#
#        Iteration  46
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00815916061401 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00140500068665 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000300884246826 s]
# --> Updating distances
# <-- Updating distances       [ 0.00099778175354 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00109100341797 s]
# _____________________________
#
#       [ 0.0189459323883 s]
# _____________________________
#
#        Iteration  47
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00844979286194 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00124597549438 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000964164733887 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101804733276 s]
# _____________________________
#
#       [ 0.0186948776245 s]
# _____________________________
#
#        Iteration  48
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00862789154053 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127792358398 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000287055969238 s]
# --> Updating distances
# <-- Updating distances       [ 0.00101113319397 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102806091309 s]
# _____________________________
#
#       [ 0.0191187858582 s]
# _____________________________
#
#        Iteration  49
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00805687904358 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00139808654785 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286817550659 s]
# --> Updating distances
# <-- Updating distances       [ 0.000982999801636 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103092193604 s]
# _____________________________
#
#       [ 0.0188989639282 s]
# _____________________________
#
#        Iteration  50
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00855803489685 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127387046814 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000967979431152 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00104999542236 s]
# _____________________________
#
#       [ 0.0189199447632 s]
# _____________________________
# --> Optimizing Topomesh    [ 0.99135017395 s]
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00151705741882 s]
# --> Computing interfaces
# <-- Computing interfaces[ 0.010724067688 s]
# --> Preparing topomesh     [ 0.201369047165 s]
# _____________________________
#
#        Iteration  0
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00919795036316 s]
# --> Computing planarization force
# Warning : missing keys were added to the dictionary!
# [[ 0.89163817  0.89888064 -2.48766017]
#  [-0.46958386  0.30403359  0.71930669]
#  [ 1.62842595  2.39842765  1.21632331]
#  ...,
#  [ 0.28788738  0.2204052  -0.63732215]
#  [-0.07276607 -0.05570935  0.16108878]
#  [ 0.26054287  0.19947037 -0.57678715]]
# <-- Computing planarization force [ 0.0181560516357 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.0110418796539 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000291109085083 s]
# --> Updating distances
# <-- Updating distances       [ 0.000977993011475 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102114677429 s]
# _____________________________
#
#       [ 0.0476830005646 s]
# _____________________________
#
#        Iteration  1
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00825619697571 s]
# --> Computing planarization force
# [[ 0.47458006  0.39233417 -1.15851717]
#  [-0.33047222  0.25127529  0.59915859]
#  [ 0.80031611  1.39537771  0.53975101]
#  ...,
#  [ 0.12837407  0.09901625 -0.28239265]
#  [ 0.01829434  0.01411061 -0.04024322]
#  [ 0.11775591  0.09082635 -0.25903521]]
# <-- Computing planarization force [ 0.00223302841187 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.0100150108337 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000294923782349 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100088119507 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00110197067261 s]
# _____________________________
#       [ 0.0302531719208 s]
# _____________________________
#
#        Iteration  2
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00855708122253 s]
# --> Computing planarization force
# [[ 0.29614562  0.2057797  -0.66771033]
#  [-0.21660347  0.20905465  0.49859579]
#  [ 0.43734822  0.89422767  0.26173618]
#  ...,
#  [ 0.06938232  0.05388015 -0.15196684]
#  [ 0.03437059  0.02669113 -0.07528128]
#  [ 0.07013442  0.05446421 -0.15361415]]
# <-- Computing planarization force [ 0.00216698646545 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.00960206985474 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00031304359436 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100708007812 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00109195709229 s]
# _____________________________
#
#       [ 0.0297830104828 s]
# _____________________________
#
#        Iteration  3
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00950717926025 s]
# --> Computing planarization force
# [[ 0.21903142  0.13403606 -0.46621998]
#  [-0.1410509   0.17417237  0.41467106]
#  [ 0.2792191   0.63466511  0.15623365]
#  ...,
#  [ 0.04645925  0.03628259 -0.1014915 ]
#  [ 0.03006906  0.02348259 -0.06568668]
#  [ 0.05347469  0.04176134 -0.11681692]]
# <-- Computing planarization force [ 0.00289797782898 s]
# --> Computing planarization force
# <-- Computing planarization force [
#  0.0106489658356 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000308990478516 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100207328796 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107192993164 s]
# _____________________________
#
#       [ 0.0327520370483 s]
# _____________________________
#
#        Iteration  4
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00854015350342 s]
# --> Computing planarization force
# [[ 0.18716848  0.10618145 -0.37657978]
#  [-0.11620798  0.14693517  0.35076899]
#  [ 0.20883802  0.49439431  0.12175352]
#  ...,
#  [ 0.03744023  0.02936892 -0.08167068]
#  [ 0.02238967  0.01756294 -0.04883998]
#  [ 0.0470785   0.03692939 -0.10269525]]
# <-- Computing planarization force [ 0.00231099128723 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.00948476791382 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000293970108032 s]
# --> Updating distances
# <-- Updating distances       [ 0.000988960266113 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106501579285 s]
# _____________________________
#
#       [ 0.0297589302063 s]
# _____________________________
#
#        Iteration  5
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00862002372742 s]
# --> Computing planarization force
# [[ 0.17545708  0.0959678  -0.33309927]
#  [-0.11667584  0.12540766  0.30117318]
#  [ 0.17586771  0.41607535  0.11458899]
#  ...,
#  [ 0.03413334  0.02686543 -0.07440952]
#  [ 0.01571376  0.01236787 -0.03425546]
#  [ 0.04429668  0.03486471 -0.09656525]]
# <-- Computing planarization force [ 0.00251507759094 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.00959515571594 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000292062759399 s]
# --> Updating distances
# <-- Updating distances       [ 0.000984907150269 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107383728027 s]
# _____________________________
#
#       [ 0.0301151275635 s]
# _____________________________
#
#        Iteration  6
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00824594497681 s]
# --> Computing planarization force
# [[ 0.17257337  0.09270782 -0.30997245]
#  [-0.12734422  0.10853447  0.26269993]
#  [ 0.16054736  0.37067192  0.11600291]
#  ...,
#  [ 0.03273674  0.02583617 -0.07136104]
#  [ 0.01048076  0.00827152 -0.02284644]
#  [ 0.04276964  0.03375424 -0.09323121]]
# <-- Computing planarization force [ 0.00214099884033 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.0100030899048 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000307083129883 s]
# --> Updating distances
# <-- Updating distances       [ 0.00123906135559 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00112700462341 s]
# _____________________________
#
#       [ 0.0304129123688 s]
# _____________________________
#
#        Iteration  7
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00842595100403 s]
# --> Computing planarization force
# [[ 0.17316908  0.0922303  -0.29690568]
#  [-0.1412877   0.09545466  0.2330419 ]
#  [ 0.15323198  0.34304441  0.11970425]
#  ...,
#  [ 0.03209688  0.0253884  -0.06998973]
#  [ 0.00659389  0.00521572 -0.01437848]
#  [ 0.0416885   0.03297531 -0.090905  ]]
# <-- Computing planarization force [ 0.00228500366211 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.00961589813232 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000287055969238 s]
# --> Updating distances
# <-- Updating distances       [ 0.00102400779724 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00104117393494 s]
# _____________________________
#
#       [ 0.0298731327057 s]
# _____________________________
#
#        Iteration  8
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00849103927612 s]
# --> Computing planarization force
# [[ 0.17495286  0.09273731 -0.28909638]
#  [-0.15528948  0.08538816  0.21026822]
#  [ 0.14966925  0.32536451  0.12352069]
#  ...,
#  [ 0.03180337  0.0252047  -0.06939082]
#  [ 0.00375543  0.00297624 -0.00819387]
#  [ 0.0407944   0.03233023 -0.08900807]]
# <-- Computing planarization force [ 0.00222706794739 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.00975203514099 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000300884246826 s]
# --> Updating distances
# <-- Updating distances       [ 0.00103616714478 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108504295349 s]
# _____________________________
#       [ 0.0300688743591 s]
# _____________________________
#
#        Iteration  9
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00874805450439 s]
# --> Computing planarization force
# [[ 0.17697726  0.09353718 -0.28402899]
#  [-0.16772765  0.07761793  0.19265744]
#  [ 0.14801021  0.31345784  0.12680483]
#  ...,
#  [ 0.03168075  0.02514954 -0.0691758 ]
#  [ 0.00167822  0.00133224 -0.00366444]
#  [ 0.03999784  0.03175201 -0.08733639]]
# <-- Computing planarization force [ 0.00225210189819 s]
# --> Computing planarization force
# <-- Computing planarization force [ 0.00951814651489 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286817550659 s]
# --> Updating distances
# <-- Updating distances       [ 0.000998973846436 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103807449341 s]
# _____________________________
#
#       [ 0.0296859741211 s]
# _____________________________
#
#        Iteration  10
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00837993621826 s]
# --> Computing planarization force
# [[  1.78850248e-01   9.43829732e-02  -2.80480684e-01]
#  [ -1.78093293e-01   7.16146548e-02   1.78981114e-01]
#  [  1.47370161e-01   3.05014087e-01   1.29480618e-01]
#  ...,
#  [  3.16505621e-02   2.51625615e-02  -6.91695840e-02]
#  [  1.45139946e-04   1.15387929e-04  -3.17190881e-04]
#  [  3.92640179e-02   3.12153465e-02  -8.58081375e-02]]
# <-- Computing planarization force [ 0.00214099884033 s]
# --> Computing planarization force
# <-- Computing planarization force [
#  0.00990080833435 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000322103500366 s]
# --> Updating distances
# <-- Updating distances       [ 0.00104308128357 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108695030212 s]
# _____________________________
#
#       [ 0.0301768779755 s]
# _____________________________
# --> Optimizing Topomesh    [ 0.352107048035 s]
# /opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/scipy/ndimage/measurements.py:634: RuntimeWarning: invalid value encountered in true_divide
#   return sum / numpy.asanyarray(count).astype(numpy.float)

# %% [markdown]
# The resulting triagular mesh is a consistent 3D reconstruction of the original image, representing the same geometry in a much more synthetic data structure. It can be used as such in applications such as biomechanical simulations of tissue growth using finite element methods.

# %%
mesh,_ = topomesh_to_triangular_mesh(image_dual_topomesh,3,coef=0.98)
vtk_show_polydata(mesh._repr_vtk_(), width=800, height=300, position=(0,0,-1.5*img.shape[2]*img.resolution[2]),colormap_name='glasbey')
# Out:
# --> Creating triangular mesh
# <-- Creating triangular mesh [
#  0.145215034485 s]

# %% [markdown]
# The mesh can be exported in standard mesh formats such as PLY for further re-use in OpenAlea or other applications.

# %%
# Uncomment to save the dual topomesh
#save_ply_property_topomesh(image_dual_topomesh,"example_topomesh.ply")
# Out:
# --> Saving .ply
# <-- Saving .ply        [
#  0.133291959763 s]
