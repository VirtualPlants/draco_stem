# %% [markdown]
# # Creating a cell tissue mesh with Draco-Stem
#
# **Draco-Stem** (**D**ual **R**econstruction by **A**djacency **C**omplex **O**ptimization - **S**AM **T**issue **E**nhanced **M**esh) is a computational pipeline allowing to convert a 3D stack containing a segmented tissue image into a FEM-ready triangular mesh of the cell interfaces.

# %%
import numpy as np
from scipy import ndimage as nd

from openalea.draco_stem.draco.draco import DracoMesh
from openalea.mesh.triangular_mesh import topomesh_to_triangular_mesh
from openalea.mesh.property_topomesh_io import save_ply_property_topomesh

# %% [markdown]
# First, let's generate a synthetic tissue image. Only the number of cells and the size of the image need to be specified, the cells divide a sphere in a rather realistic tissue-like way.

# %%
from openalea.draco_stem.data.example_image import sphere_tissue_image

n_cells = 21
size = 100
img = sphere_tissue_image(size,n_cells)
# Out:
# (100, 100, 100)

# %% [markdown]
# The output is a 3D image stack in which the backgound is labelled as 1, and each cell comes with its own label. The cells form neighboring connected regions of voxels.

# %%
from vplants.meshing.notebook_tools import vtk_show_image, vtk_show_polydata
vtk_show_image(img, width=800, height=300, alphamap='constant', bg_id=1, 
               position=(0,0,-1.5*img.shape[2]*img.resolution[2]))

# %% [markdown]
# To convert the image into an interface mesh, **Draco-Stem** operates on the adjacency relationships between tissue cells. It aims at reconstructing a *simplicial complex* joining neighboring cell barycenters. This complex constitutes the dual of the tissue geometry seen as a cellular complex.
#
# The algorithm uses an object called **DracoMesh** implementing all the steps of the pipeline. The initialization consists in extracting the adjacency tetrahedra from the image that *do not necessarily* constitute a simplicial complex.
#
# This is why the first step consists in generating a valid simplicial complex, as the Delaunay tetrahedrization of the cell barycenters. The key step of the pipeline is the **topological optimization** of this complex so that, in the end, it reflects as well as possible the adjacencies found in the image.

# %%
# Initialize the DracoMesh object with the example image
draco = DracoMesh(image=img)

draco.delaunay_adjacency_complex(surface_cleaning_criteria = [])

draco.adjacency_complex_optimization(n_iterations=1)
# Out:
# Computing volume property...
# Computing barycenter property...
# Generating the list of cells belonging to the first layer...
# --> Generating vertex topomesh
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating vertex topomesh [ 0.000178813934326 s]
# --> Generating tetrahedra topomesh
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating tetrahedra topomesh [ 0.00227999687195 s]
# Computing barycenter property...
# Generating the list of cells belonging to the first layer...
# property layer is undefined on elements of degree 0
# Creating property  layer  for degree  0
# --> Generating edge topomesh
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating edge topomesh [ 0.00049901008606 s]
# --> Generating triangulation topomesh
# 43  cell vertices
# 0  5-Cliques remaining
# 43  cell vertices (+exterior)
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# <-- Generating triangulation topomesh [ 0.00477194786072 s]
# property borders is undefined on elements of degree 1
# Creating property  borders  for degree  1
# property normal is undefined on elements of degree 0
# Creating property  normal  for degree  0
# _____________________________
#
# Iteration  0
# _____________________________
#
# --> Computing edge flip energy variations [
#  0.25213599205 s]
#   --> Flipped edge  49  :  [24L, 6L, 39L]  ->  [81 82]  (dE =  -20.9736825998 ) [ 0.00111413002014 s]
#   --> Flipped edge  70  :  [41L, 34L, 29L]  ->  [ 6 24]  (dE =  -20.8013427881 ) [ 0.000880002975464 s]
#   --> Flipped edge  34  :  [40L, 13L, 14L]  ->  [29 34]  (dE =  -20.7998999774 ) [ 0.000859022140503 s]
#   --> Flipped edge  63  :  [32L, 42L, 31L]  ->  [39 40]  (dE =  -20.7923306115 ) [ 0.000859022140503 s]
# 4  Edges Flipped ( 0  non-optimal) [ 0.0100660324097 s]
# <-- Computing triangle flip energy variations [
#  0.237097024918 s]
#   --> Flipped triangle  0  :  [0L, 1L]  ->  [41 42 13]  (dE =  0.450216551167 ) [ 0.000963926315308 s]
# 1  Triangles Flipped ( 1  non-optimal) [ 0.0325322151184 s]
# Cell interface Jaccard (2-adjacency) :
#  0.990099009901
# Cell vertices Jaccard  (4-adjacency) :  0.961538461538
# --> Computing edge flip energy variations [
#  0.24497294426 s]
# 0  Edges Flipped ( 0  non-optimal) [ 0.0125761032104 s]
# <-- Computing triangle flip energy variations [
#  0.244570016861 s]
# 0  Triangles Flipped ( 0  non-optimal) [ 0.0342879295349 s]
# Cell interface Jaccard (2-adjacency) :
#  0.990099009901
# Cell vertices Jaccard  (4-adjacency) :  0.961538461538

# %% [markdown]
# At this stage, what we obtain is a tetrahedral mesh representing the adjacencies between cells in the image

# %%
mesh,_ = topomesh_to_triangular_mesh(draco.triangulation_topomesh,3,coef=0.9)
vtk_show_polydata(mesh._repr_vtk_(), width=800, height=300, colormap_name='grey',
                  intensity_range=(-1,0), position=(0,0,-1.2*img.shape[2]*img.resolution[2]))
# Out:
# --> Creating triangular mesh
# <-- Creating triangular mesh [ 0.0129950046539 s]

# %% [markdown]
# Now, to obtain a mesh of the tissue geometry, we only need to **dualize** the adjacency complex. This is a very straightforward process, in which the tetrahedra convert into vertices, the triangles into edges, and so on... Only the dimensionality is inverted, the topological relationships between elements are preserved.
#
# However, this produces cells with polygonal interfaces that need to be triangulated to be used for visualization of biophysical simulations. To ensure the quality of these triangles, several options are made available, controlling the fineness, regularity and faithfulness of the mesh.

# %%
#triangular = ['star','remeshed','realistic','flat']
triangular = ['star','split','regular','projected']
image_dual_topomesh = draco.dual_reconstruction(reconstruction_triangulation = triangular, adjacency_complex_degree=3)
# Out:
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# --> Creating vertices
# <-- Creating vertices      [
#  0.0358459949493 ]
# --> Creating edges
# <-- Creating edges         [ 0.0031430721283 ]
# --> Creating facets
# <-- Creating facets        [ 0.00401496887207 ]
# --> Creating cells
# <-- Creating cells         [ 0.00068998336792 ]
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# --> Triangulating Interfaces
#   --> Interface  0  /  99      [ 0.000294923782349 s]
# --> Triangulating Interfaces  [ 0.0138118267059 s]
# property barycenter is undefined on elements of degree 0
# Creating property  barycenter  for degree  0
# --> Splitting edges
# --> Splitting edges             [ 0.0160989761353 s]
# --> Splitting triangles
# --> Splitting triangles         [
#  0.0548689365387 s]
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00949287414551 s]
# --> Preparing topomesh     [
#  0.208858013153 s]
# _____________________________
#
#        Iteration  0
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0114870071411 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00157403945923 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000313997268677 s]
# --> Updating distances
# <-- Updating distances       [ 0.000990867614746 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107717514038 s]
# _____________________________
#
#       [ 0.0222480297089 s]
# _____________________________
#
#        Iteration  1
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00861096382141 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00123500823975 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000279188156128 s]
# --> Updating distances
# <-- Updating distances       [ 0.000935077667236 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102710723877 s]
# _____________________________
#
#       [ 0.0188641548157 s]
# _____________________________
#
#        Iteration  2
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0080029964447 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [
#  0.0011830329895 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000308990478516 s]
# --> Updating distances
# <-- Updating distances       [ 0.000967979431152 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101494789124 s]
# _____________________________
#
#       [ 0.0186059474945 s]
# _____________________________
#
#        Iteration  3
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00960493087769 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00136208534241 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000964879989624 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106000900269 s]
# _____________________________
#
#       [ 0.0200219154358 s]
# _____________________________
#
#        Iteration  4
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00848913192749 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00122094154358 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000277996063232 s]
# --> Updating distances
# <-- Updating distances       [ 0.000956058502197 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.000988006591797 s]
# _____________________________
#
#       [ 0.0184860229492 s]
# _____________________________
#
#        Iteration  5
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.0082151889801 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00142312049866 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000280857086182 s]
# --> Updating distances
# <-- Updating distances       [ 0.000936031341553 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105595588684 s]
# _____________________________
#
#       [ 0.0192291736603 s]
# _____________________________
#
#        Iteration  6
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00890898704529 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127601623535 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000967979431152 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102186203003 s]
# _____________________________
#
#       [ 0.019299030304 s]
# _____________________________
#
#        Iteration  7
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00815200805664 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00119090080261 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000279188156128 s]
# --> Updating distances
# <-- Updating distances       [ 0.000960111618042 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.000991106033325 s]
# _____________________________
#
#       [ 0.0182600021362 s]
# _____________________________
#
#        Iteration  8
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.0080668926239 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00136494636536 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.000972032546997 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106692314148 s]
# _____________________________
#
#       [ 0.0190408229828 s]
# _____________________________
#
#        Iteration  9
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00846910476685 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00133395195007 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288963317871 s]
# --> Updating distances
# <-- Updating distances       [ 0.00102400779724 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00113606452942 s]
# _____________________________
#
#       [ 0.0194199085236 s]
# _____________________________
#
#        Iteration  10
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00853991508484 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00126791000366 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00028395652771 s]
# --> Updating distances
# <-- Updating distances       [ 0.000977993011475 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106501579285 s]
# _____________________________
#
#       [ 0.0187790393829 s]
# _____________________________
#
#        Iteration  11
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00826001167297 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00141596794128 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.000975131988525 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00104808807373 s]
# _____________________________
#
#       [ 0.0189700126648 s]
# _____________________________
#
#        Iteration  12
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0088939666748 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00132989883423 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000951051712036 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00104403495789 s]
# _____________________________
#
#       [ 0.0194408893585 s]
# _____________________________
#
#        Iteration  13
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00801014900208 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00126910209656 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000280141830444 s]
# --> Updating distances
# <-- Updating distances       [ 0.000972986221313 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101804733276 s]
# _____________________________
#
#       [ 0.0182828903198 s]
# _____________________________
#
#        Iteration  14
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00809001922607 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00140786170959 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.000976085662842 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101900100708 s]
# _____________________________
#
#       [ 0.0187449455261 s]
# _____________________________
#
#        Iteration  15
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00863814353943 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00128507614136 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.00102496147156 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103616714478 s]
# _____________________________
#
#       [ 0.0188820362091 s]
# _____________________________
#
#        Iteration  16
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0079870223999 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00128507614136 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000284910202026 s]
# --> Updating distances
# <-- Updating distances       [ 0.000965118408203 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.000999927520752 s]
# _____________________________
#
#       [ 0.0180740356445 s]
# _____________________________
#
#        Iteration  17
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00811290740967 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00139307975769 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000284910202026 s]
# --> Updating distances
# <-- Updating distances       [ 0.00097393989563 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102400779724 s]
# _____________________________
#
#       [ 0.0188200473785 s]
# _____________________________
#
#        Iteration  18
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00850605964661 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00131297111511 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288963317871 s]
# --> Updating distances
# <-- Updating distances       [ 0.000976085662842 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105905532837 s]
# _____________________________
#
#       [ 0.0188980102539 s]
# _____________________________
#
#        Iteration  19
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00832009315491 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00123405456543 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000281095504761 s]
# --> Updating distances
# <-- Updating distances       [ 0.000998020172119 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00109004974365 s]
# _____________________________
#
#       [ 0.0186290740967 s]
# _____________________________
#
#        Iteration  20
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.0081160068512 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00139093399048 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000281810760498 s]
# --> Updating distances
# <-- Updating distances       [ 0.000979900360107 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101804733276 s]
# _____________________________
#
#       [ 0.0188498497009 s]
# _____________________________
#
#        Iteration  21
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00848603248596 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00132608413696 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286102294922 s]
# --> Updating distances
# <-- Updating distances       [ 0.00102210044861 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00114011764526 s]
# _____________________________
#
#       [ 0.0192260742188 s]
# _____________________________
#
#        Iteration  22
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00804710388184 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.0011899471283 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000278949737549 s]
# --> Updating distances
# <-- Updating distances       [ 0.000967979431152 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106883049011 s]
# _____________________________
#
#       [ 0.0187079906464 s]
# _____________________________
#
#        Iteration  23
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00842499732971 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00140404701233 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00028395652771 s]
# --> Updating distances
# <-- Updating distances       [ 0.000982999801636 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102400779724 s]
# _____________________________
#
#       [ 0.0191171169281 s]
# _____________________________
#
#        Iteration  24
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00839114189148 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00142502784729 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.000981092453003 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107979774475 s]
# _____________________________
#
#       [ 0.0191860198975 s]
# _____________________________
#
#        Iteration  25
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00886011123657 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00121688842773 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000281810760498 s]
# --> Updating distances
# <-- Updating distances       [ 0.000964879989624 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00116181373596 s]
# _____________________________
#
#       [ 0.0192189216614 s]
# _____________________________
#
#        Iteration  26
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00810790061951 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00139307975769 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000982999801636 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0010461807251 s]
# _____________________________
#
#       [ 0.0187849998474 s]
# _____________________________
#
#        Iteration  27
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00829792022705 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00135087966919 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000308036804199 s]
# --> Updating distances
# <-- Updating distances       [ 0.000993013381958 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107407569885 s]
# _____________________________
#
#       [ 0.019091129303 s]
# _____________________________
#
#        Iteration  28
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00847506523132 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00124597549438 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000280857086182 s]
# --> Updating distances
# <-- Updating distances       [ 0.000968933105469 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00114488601685 s]
# _____________________________
#
#       [ 0.0188009738922 s]
# _____________________________
#
#        Iteration  29
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00837302207947 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00141906738281 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000284194946289 s]
# --> Updating distances
# <-- Updating distances       [ 0.00102806091309 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108098983765 s]
# _____________________________
#
#       [ 0.0194799900055 s]
# _____________________________
#
#        Iteration  30
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00845909118652 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127601623535 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000976085662842 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105905532837 s]
# _____________________________
#
#       [ 0.0190360546112 s]
# _____________________________
#
#        Iteration  31
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00851511955261 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00123190879822 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000280857086182 s]
# --> Updating distances
# <-- Updating distances       [ 0.000960826873779 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0010199546814 s]
# _____________________________
#
#       [ 0.018627166748 s]
# _____________________________
#
#        Iteration  32
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00834488868713 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00143790245056 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000286102294922 s]
# --> Updating distances
# <-- Updating distances       [ 0.00098705291748 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102281570435 s]
# _____________________________
#
#       [ 0.0191159248352 s]
# _____________________________
#
#        Iteration  33
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0082700252533 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00123500823975 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000978946685791 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00111603736877 s]
# _____________________________
#
#       [ 0.01935505867 s]
# _____________________________
#
#        Iteration  34
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00849604606628 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00119686126709 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000278949737549 s]
# --> Updating distances
# <-- Updating distances       [ 0.00101518630981 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.000990867614746 s]
# _____________________________
#
#       [ 0.0186879634857 s]
# _____________________________
#
#        Iteration  35
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00838899612427 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00142812728882 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285148620605 s]
# --> Updating distances
# <-- Updating distances       [ 0.000993967056274 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107407569885 s]
# _____________________________
#
#       [ 0.0192749500275 s]
# _____________________________
#
#        Iteration  36
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00816512107849 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00126481056213 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288009643555 s]
# --> Updating distances
# <-- Updating distances       [ 0.000970840454102 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103306770325 s]
# _____________________________
#
#       [ 0.0188119411469 s]
# _____________________________
#
#        Iteration  37
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00847887992859 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00121402740479 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000281095504761 s]
# --> Updating distances
# <-- Updating distances       [ 0.000977993011475 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00104713439941 s]
# _____________________________
#
#       [ 0.0185258388519 s]
# _____________________________
#
#        Iteration  38
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00819087028503 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00139904022217 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000288009643555 s]
# --> Updating distances
# <-- Updating distances       [ 0.000986099243164 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102615356445 s]
# _____________________________
#
#       [ 0.0189578533173 s]
# _____________________________
#
#        Iteration  39
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00844597816467 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.0012412071228 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000964879989624 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102686882019 s]
# _____________________________
#
#       [ 0.0189280509949 s]
# _____________________________
#
#        Iteration  40
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00853419303894 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.0012218952179 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000279903411865 s]
# --> Updating distances
# <-- Updating distances       [ 0.000964164733887 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0010781288147 s]
# _____________________________
#
#       [ 0.0189001560211 s]
# _____________________________
#
#        Iteration  41
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00824093818665 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00144600868225 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000284910202026 s]
# --> Updating distances
# <-- Updating distances       [ 0.000997066497803 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102186203003 s]
# _____________________________
#
#       [ 0.0191290378571 s]
# _____________________________
#
#        Iteration  42
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00811219215393 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00124406814575 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000294923782349 s]
# --> Updating distances
# <-- Updating distances       [ 0.00096321105957 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00101804733276 s]
# _____________________________
#
#       [ 0.0185780525208 s]
# _____________________________
#
#        Iteration  43
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00871300697327 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127387046814 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000293016433716 s]
# --> Updating distances
# <-- Updating distances       [ 0.000996112823486 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.000990867614746 s]
# _____________________________
#
#       [ 0.0189960002899 s]
# _____________________________
#
#        Iteration  44
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00790691375732 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00189590454102 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000301122665405 s]
# --> Updating distances
# <-- Updating distances       [ 0.00118899345398 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103497505188 s]
# _____________________________
#
#       [ 0.0195200443268 s]
# _____________________________
#
#        Iteration  45
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00878691673279 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00125217437744 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100493431091 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106191635132 s]
# _____________________________
#
#       [ 0.0205659866333 s]
# _____________________________
#
#        Iteration  46
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0114421844482 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00137209892273 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000281810760498 s]
# --> Updating distances
# <-- Updating distances       [ 0.000962972640991 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.000998973846436 s]
# _____________________________
#       [ 0.0219218730927 s]
# _____________________________
#
#        Iteration  47
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00857186317444 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00127387046814 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000969886779785 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.001051902771 s]
# _____________________________
#
#       [ 0.0190258026123 s]
# _____________________________
#
#        Iteration  48
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.0085301399231 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00122499465942 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000982999801636 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00107908248901 s]
# _____________________________
#
#       [ 0.0191769599915 s]
# _____________________________
#
#        Iteration  49
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.008465051651 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00126814842224 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.00029993057251 s]
# --> Updating distances
# <-- Updating distances       [ 0.000982046127319 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0014431476593 s]
# _____________________________
#
#       [ 0.0195939540863 s]
# _____________________________
#
#        Iteration  50
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00857400894165 s]
# --> Computing epidermis convexity force
# <-- Computing epidermis convexity force [ 0.00126886367798 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.000972986221313 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00102210044861 s]
# _____________________________
#
#       [ 0.0188360214233 s]
# _____________________________
# --> Optimizing Topomesh    [ 0.979560852051 s]
# property normal is undefined on elements of degree 0
# Creating property  normal  for degree  0
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00151491165161 s]
# --> Preparing topomesh     [ 0.180850982666 s]
# _____________________________
#
#        Iteration  0
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00864410400391 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000293016433716 s]
# --> Updating distances
# <-- Updating distances       [ 0.00182509422302 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00142312049866 s]
# _____________________________
#
#       [ 0.0214328765869 s]
# _____________________________
#
#        Iteration  1
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00843596458435 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000297069549561 s]
# --> Updating distances
# <-- Updating distances       [ 0.00100207328796 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103116035461 s]
# _____________________________
#
#       [ 0.0178139209747 s]
# _____________________________
#
#        Iteration  2
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00817012786865 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000277996063232 s]
# --> Updating distances
# <-- Updating distances       [ 0.000940084457397 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.0010199546814 s]
# _____________________________
#
#       [ 0.0171129703522 s]
# _____________________________
#
#        Iteration  3
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00831198692322 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000296115875244 s]
# --> Updating distances
# <-- Updating distances       [ 0.000988006591797 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00108599662781 s]
# _____________________________
#
#       [ 0.0177371501923 s]
# _____________________________
#
#        Iteration  4
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00825595855713 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000311136245728 s]
# --> Updating distances
# <-- Updating distances       [ 0.000993967056274 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00105881690979 s]
# _____________________________
#
#       [ 0.0177779197693 s]
# _____________________________
#
#        Iteration  5
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00817894935608 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000988006591797 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103187561035 s]
# _____________________________
#
#       [ 0.0172810554504 s]
# _____________________________
#
#        Iteration  6
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00810217857361 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000283002853394 s]
# --> Updating distances
# <-- Updating distances       [ 0.00101184844971 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00109696388245 s]
# _____________________________
#
#       [ 0.017657995224 s]
# _____________________________
#
#        Iteration  7
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00811100006104 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000306129455566 s]
# --> Updating distances
# <-- Updating distances       [ 0.0010359287262 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103092193604 s]
# _____________________________
#
#       [ 0.0176100730896 s]
# _____________________________
#
#        Iteration  8
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00854992866516 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000282049179077 s]
# --> Updating distances
# <-- Updating distances       [ 0.000978946685791 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00103807449341 s]
# _____________________________
#
#       [ 0.0176510810852 s]
# _____________________________
#
#        Iteration  9
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [ 0.00825595855713 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000285863876343 s]
# --> Updating distances
# <-- Updating distances       [ 0.000980854034424 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00109100341797 s]
# _____________________________
#
#       [ 0.01775598526 s]
# _____________________________
#
#        Iteration  10
# _____________________________
# --> Computing taubin smoothing force
# <-- Computing taubin smoothing force [
#  0.00821995735168 s]
# --> Applying Forces
# <-- Applying Forces          [ 0.000306129455566 s]
# --> Updating distances
# <-- Updating distances       [ 0.000976800918579 s]
# 783  Vertices,  1824  Triangles,  22  Cells
# --> Computing triangle properties
# <-- Computing triangle properties    [ 0.00106906890869 s]
# _____________________________
#
#       [ 0.0177729129791 s]
# _____________________________
# --> Optimizing Topomesh    [ 0.198580026627 s]

# %% [markdown]
# The resulting triagular mesh is a consistent 3D reconstruction of the original image, representing the same geometry in a much more synthetic data structure. It can be used as such in applications such as biomechanical simulations of tissue growth using finite element methods.

# %%
mesh,_ = topomesh_to_triangular_mesh(image_dual_topomesh,3,coef=0.98)
vtk_show_polydata(mesh._repr_vtk_(), width=800, height=300, position=(0,0,-1.5*img.shape[2]*img.resolution[2]),colormap_name='glasbey')
# Out:
# --> Creating triangular mesh
# <-- Creating triangular mesh [
#  0.146872997284 s]

# %% [markdown]
# The mesh can be exported in standard mesh formats such as PLY for further re-use in OpenAlea or other applications.

# %%
# Uncomment to save the dual topomesh
#save_ply_property_topomesh(image_dual_topomesh,"example_topomesh.ply")
